# %%
##함수 선언

def add_data(friend):
    
    katok.append(None)
    klen=len(katok)
    katok[klen-1]=friend
    
def delete_data(position):
    
    if position <0 or position >len(katok):
        print("데이터를 삭제할 범위를 벗어났습니다.")
        return
    
    klen=len(katok)
    katok[position]=None
    
    for i in range(position+1, klen):
        katok[i-1]=katok[i]
        katok[i]=None
        
    del(katok[klen-1])
    
    
## 전역 변수 선언

katok=[]
select = -1 ##1:추가, 2:삭제, 3:종료


## 메인 코드

if __name__ =="__main__":
    
    while (select != 3):
        
        select=int(input("선택하세요(1:추가, 2:삭제, 3:종료)-->"))
                
        if(select==1):
            data=input("추가할 데이터 -->")
            add_data(data)
            print(katok)
        elif(select==2):
            pos=int(input("삭제할 위치-->"))
            delete_data(pos)
            print(katok)
        elif(select==3):
            print(katok)
            exit
        else:
            print("1~3중 하나를 입력하세요.")
            continue
# Out:
# 선택하세요(1:추가, 2:삭제, 3:종료)-->1
# 추가할 데이터 -->('정연', 200)
# ["('정연', 200)"]
# 선택하세요(1:추가, 2:삭제, 3:종료)-->1
# 추가할 데이터 -->('사나', 170)
# ["('정연', 200)", "('사나', 170)"]
# 선택하세요(1:추가, 2:삭제, 3:종료)-->1
# 추가할 데이터 -->('쯔위', 150)
# ["('정연', 200)", "('사나', 170)", "('쯔위', 150)"]
# 선택하세요(1:추가, 2:삭제, 3:종료)-->3
# ["('정연', 200)", "('사나', 170)", "('쯔위', 150)"]

# %%
##함수 선언

def add_data(position, friend):
    
    katok.append(None)
    klen=len(katok)
    katok[klen-1]=friend
    
    for i in range(position+1, klen):
        j = klen(position)-i
        for i in range(1, j):
            if position[i-1] < position[i]:
                friend=position[i-1]
                position[i-1]=position[i]
                
                katok[position]=friend
    
def delete_data(position):
    
    if position <0 or position >len(katok):
        print("데이터를 삭제할 범위를 벗어났습니다.")
        return
    
    klen=len(katok)
    katok[position]=None
    
    for i in range(position+1, klen):
        katok[i-1]=katok[i]
        katok[i]=None
            
    del(katok[klen-1])
    
    
## 전역 변수 선언

katok=[]
select = -1 ##1:추가, 2:삭제, 3:종료


## 메인 코드

if __name__ =="__main__":
    
    while (select != 3):
        
        select=int(input("선택하세요(1:추가, 2:삭제, 3:종료)-->"))
                
        if(select==1):
            data=input("추가할 데이터 -->")
            add_data(pos, data)
            print(katok)
        elif(select==2):
            pos=int(input("삭제할 위치-->"))
            delete_data(pos)
            print(katok)
        elif(select==3):
            print(katok)
            exit
        else:
            print("1~3중 하나를 입력하세요.")
            continue
# Out:
# 선택하세요(1:추가, 2:삭제, 3:종료)-->1
# 추가할 데이터 -->('정연', 200)
# ["('정연', 200)"]
# 선택하세요(1:추가, 2:삭제, 3:종료)-->1
# 추가할 데이터 -->('사나', 100)
# ["('정연', 200)", "('사나', 100)"]
# 선택하세요(1:추가, 2:삭제, 3:종료)-->1
# 추가할 데이터 -->('쯔위', 150)
# ["('정연', 200)", "('사나', 100)", "('쯔위', 150)"]
# 선택하세요(1:추가, 2:삭제, 3:종료)-->2
# 삭제할 위치-->1
# ["('정연', 200)", "('쯔위', 150)"]
# 선택하세요(1:추가, 2:삭제, 3:종료)-->3
# ["('정연', 200)", "('쯔위', 150)"]

# %%
##함수 선언

def add_data(position, friend):
    
    katok.append(None)
    klen=len(katok)
    katok[klen-1]=friend
    
    for i in range(position+1, klen):
        i=(%s, %d)
        j = klen(position)-i
        for i in range(1, j):
            if position[i-1] < position[i]:
                friend=position[i-1]
                position[i-1]=position[i]
                
                katok[position]=friend
    
def delete_data(position):
    
    if position <0 or position >len(katok):
        print("데이터를 삭제할 범위를 벗어났습니다.")
        return
    
    klen=len(katok)
    katok[position]=None
    
    for i in range(position+1, klen):
        katok[i-1]=katok[i]
        katok[i]=None
            
    del(katok[klen-1])
    
    
## 전역 변수 선언

katok=[]
select = -1 ##1:추가, 2:삭제, 3:종료


## 메인 코드

if __name__ =="__main__":
    
    while (select != 3):
        
        select=int(input("선택하세요(1:추가, 2:삭제, 3:종료)-->"))
                
        if(select==1):
            data=input("추가할 데이터 -->")
            add_data(pos, data)
            print(katok)
        elif(select==2):
            pos=int(input("삭제할 위치-->"))
            delete_data(pos)
            print(katok)
        elif(select==3):
            print(katok)
            exit
        else:
            print("1~3중 하나를 입력하세요.")
            continue
# Out:
#   File "C:\Users\kimsu\AppData\Local\Temp/ipykernel_25844/2101244251.py", line 10
#     i=(%s, %d)
#        ^
# SyntaxError: invalid syntax
